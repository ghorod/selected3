# %%
import csv

def menu():
    print("Welcome, \n 1.read the file \n 2. Print row 1 \n 3. print row 2 ")
    print("\n 4. Print row 3 \n 5. Print row 4 \n 6. Print row5")
    print("\n 7. Print rowe \n 8. write the file \n 9. search in file ")
    choice = input()
    
    if choice =="1":
     with open ("oscar_age_female.csv","r") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          scoreslist=[]
          for row in scoresFileReader:
              if len (row) !=0:
                  print (row)
     scoresfile.close()
    
    if choice =="2":
     with open("oscar_age_female.csv", "r") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          for row in scoresFileReader:
              print(row[0])
     scoresFile.close()
        
    if choice =="3":
     with open("oscar_age_female.csv","r") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          for row in scoresFileReader:
              print(row[1])
     scoresFile.close()
        
    if choice =="4":
     with open("oscar_age_female.csv","r") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          for row in scoresFileReader:
              print(row[2])
     scoresFile.close()
        
    if choice =="5":
     with open("oscar_age_female.csv","r") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          for row in scoresFileReader:
             print(row[3])
     scoresFile.close()
        
    if choice =="6":
     with open("scores.txt","r") as scoresFile:
          scoresFileReader=csv.reader(scoresfile)
          for row in scoresFileReader:
            for row in scoresFileReader:
                print(row[4])
     scoresFile.close()

    if choice =="7":
     with open("scores.txt","") as scoresFile:
          scoresFileReader=csv.reader(scoresFile)
          for row in scoresFileReader:
            for row in scoresFileReader:
                print(row[5])
     scoresFile.close() 
    
    if choice =="8":
   

   firstname=input ("Enter the First name:")
      surname=input("Enter the surname:")
      gender=input ("Enter the gender: ")
      s1=input("Enter the score 1:")
      s2=input("Enter the score 2:")
      s3=input("Enter the score 3:")

      with open("oscar_age_female.csv","a") as scoresFile:
            scoresFilewriter=csv.writer(scoresFile)
            scoresFileWriter.writerow([firstname, surname, gender, s1, s2, s3])
      scoresFile.close()

    if choice =="9":
     with open("oscar_age_female.csv","r") as scoresFile:
          gender=input ("Enter the gender:")
          scoresFileReader=csv.reader(scoresFile)

         for row in scoresFileReader:
           for row in scoresFileReader:
             for field in row:
              if field == gender:
                print(row)
      scoresFile.close()
menu()
# Out:
#   File "<tokenize>", line 78
#     for row in scoresFileReader:
#     ^
# IndentationError: unindent does not match any outer indentation level
