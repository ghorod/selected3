# %%
import re
from collections import Counter
import numpy as np
import pandas as pd

# %%
import unicodedata
import string
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer


def remove_punctuation(text):
    """Remove punctuation from list of tokenized words"""
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)


def replace_numbers(text):
    """Replace all interger occurrences in list of tokenized words with textual representation"""
    return re.sub(r'\d+', '', text)


def remove_whitespaces(text):
    return text.strip()

#def stem_words(words):
 #   """Stem words in text"""
  #  stemmer = PorterStemmer()
   # return [stemmer.stem(word) for word in words]

def text2words(text):
    return word_tokenize(text)

def normalize_text( text):
    text = remove_punctuation(text)
    text = replace_numbers(text)
    words = text2words(text)
   
    #words = stem_words(words)# Eitherstem ovocar lemmatize
   

    return words

# %%
def readstr(Path): 
    f = open(Path, "r",encoding='UTF8')
    str1 = "" 
    for x in f:
        str1=str1+x
    return  str1 

def get_count(word_l):
    word_count_dict = {}  
    word_count_dict = Counter(word_l) 
    return word_count_dict
def get_probs(word_count_dict):
    probs = {} 
    m = sum(word_count_dict.values())
    for key in word_count_dict.keys():
        probs[key] = word_count_dict[key] / m
    ### END CODE HERE ###
    return probs

# %%
Str = readstr('dataset.txt')
wold_clean = normalize_text(Str)  # this will be your new vocabulary#print(wold_cleaan)
#ودي هي الفوكاب بس متكرر فيها بعد الكلمات
vocab = set(wold_clean)  # this will be your new vocabulary
word_count_dict = get_count(wold_clean)#دي فيها عدد مرات ضهور كلمه معينه
print(word_count_dict.get('العلم',0))
probs = get_probs(word_count_dict)#دي بتحسب الاحتمال بتاع كل كلمه
print(vocab)
# Out:
# 6
# {'تصورّ', 'اليوم', 'ماهية', 'أعهر', 'طيه', 'توهمه', 'مهتد', 'تبذل', 'مستقرة', 'متشابهين', 'ألقاهما', 'يقين', 'المعاني', 'المحددات', 'يوم', 'لأبي', 'المعروفة', 'يختتنون', 'الاتصال', 'برهة', 'أنجع', 'أحمد', 'ليتزوج', 'بالثقافة', 'تساق', 'اكتشفوا', 'يبدو', 'أني', 'رمضان', 'ينشأ', 'م', 'كما', 'ابتكاریون', 'تنشئ', 'ينخفض', 'الجزري', 'ميول', 'يقف', 'فيهم', 'والانطواء', 'يثاب', 'مستوفى', 'مقابلة', 'داخل', 'الإسراع', 'وإجماعا', 'فائدته', 'درس', 'قومي', 'الوجوه', 'أخلوا', 'المسيح', 'وفني', 'تعـلـم', 'وتوجه', 'الموقف', 'والفضل', 'جفن', 'غيروا', 'مكانية', 'رياضة', 'افراز', 'خليفة', 'يميل', 'العضوي', 'محن', 'فالمرأة', 'بن', 'النية', 'سواء', 'نقصصهم', 'يمتلكها', 'معها', 'والطيبة', 'رحلناها', 'والشغف', 'جوابـه', 'وجاهك', 'النصائح', 'فتسود', 'علو', 'للذين', 'نظريته', 'وغرائز', 'بعيدة', 'بهم', 'الإجابة', 'الابقاء', 'شهق', 'متحكم', 'لله', 'نعرف', 'المرجوة', 'وكذلك', 'للاحداث', 'العبد', 'وتعزيزها', 'خاصة', 'المدرسة', 'كويِدَ', 'تفيضان', 'تقوي', 'ومغالبة', 'حسن', 'أحدكم', 'يغفر', 'مجدا', 'للنيل', 'وممتلكاتهم', 'والنصارى', 'الخيبة', 'ألغته', 'تأثر', 'حواليه', 'تحمل', 'تعلمي', 'أقام', 'تتساوى', 'يهن', 'المتفرغين', 'للمهالك', 'الجزع', 'المغاضبة', 'تدفعه', 'أما', 'طاقة', 'لك', 'الأندلسي', 'الكرامة', 'كالركوع', 'استولى', 'أدل', 'أتى', 'وأهل', 'وحبه', 'كأهل', 'للحكم', 'عداوته', 'إلزام', 'مطلقا', 'وإلحاقه', 'فأمسك', 'متنوعة', 'شكره', 'دامى', 'صورة', 'وإعطاء', 'الأفراد', 'والفارسية', 'وسرى', 'المنزل', 'أخي', 'عُدمه', 'لم', 'فالمنصر', 'مودة', 'لك،', 'الظروف', 'درجات', 'وال', 'وقاطع', 'الهدى', 'الدفاعات', 'طه', 'عوامل', 'التدخين', 'البيئة', 'الجماعة', 'منظم', 'التهويل', 'نهائي', 'تقريب', 'رحيلي', 'رغبة', 'أسوأ', 'ولذا', 'ويدخل', 'وسلم', 'المجموع', 'بغرض', 'مداراة', 'والقاتل', 'ولكنه', 'وسيطر', 'التيَّاه', 'وعيناها', 'بذوي', 'الانتشار', 'الحمل', 'أمري', 'تقويم', 'فرحا', 'يرث', 'النوم', 'منكم', 'سلطانه', 'الرشوة', 'فانتقل', 'تضمنت', 'الإيثار', 'أحمل', 'ورد', 'الثالثة', 'العوامل', 'فلاح', 'معا', 'تشمله', 'انجلترا', 'يستخدم', 'وجب', 'كالتسبيع', 'عصبية', 'استجابة', 'فأنخدع', 'الخارقة', 'الصور', 'الخلافة', 'المقبولية', 'مصيبته', 'جوارحك', 'خاص', 'فيأتي', 'مقرب', 'مبشرا', 'ليعبر', 'تنفير', 'سلوكية', 'يعنيك', 'بذلك', 'موضوع', 'الظني', 'الوظيفي', 'جاه', 'خراف', 'ورزقنا', 'وسيفي', 'لمصدر', 'الكتب', 'حجة', 'وتوغل', 'القود', 'بالوراثة', 'وظيفيا', 'حضور', 'كرم', 'قدرتنا', 'كقياس', 'السيد', 'إني', 'ذللتنا', 'المنصوص', 'ولو', 'وكراهة', 'الحشوش', 'بالحاضر', 'مانع', 'نافلة', 'واستمر', 'ويخاطب', 'لدراسة', 'شالت', 'يخص', 'البين', 'الآية', 'أمره', 'للإصابة', 'بتدريب', 'يهيئ', 'جداً', 'تفسيرا', 'أموالهم', 'المرسل', 'الصناعات', 'هذين', 'وبناء', 'انتشاره', 'يحكم', 'ذاكرتهم', 'الاثنين', 'منك', 'عناصر', 'الخط', 'مستحسنة', 'الجماع', 'ملك', 'Experience', 'ولما', 'تكلمنا', 'فأدخل', 'الدافعية', 'تتحول', 'نفسي', 'استثارتهم', 'عمومية', 'غرور', 'تفرد', 'ينشئه', 'وترابطها', 'النشء', 'لأعلم', 'يعول', 'شاهدت', 'حجابا', 'نعرفها', 'والاهتمام', 'السنغال', 'المشاهدة', 'للقعود', 'العثرات', 'العلاجية', 'الصناديق', 'الحقدا', 'فمضمون', 'رد', 'العصابيين', 'بنيهم', 'عاملها', 'نهد', 'سلم', 'بثوا', 'صحيحا', 'فلكي', 'المواقف', 'رميا', 'الوجهين', 'تأمنه', 'أي', 'أجل', 'وأولي', 'أجلها', 'الاستكثار', 'يحرص', 'بيني', 'فسيطرت', 'والذين', 'الاستجابي', 'بالمحبة', 'ذبيان', 'وتتوزع', 'قلناه', 'الاستجابة', 'المسلمين', 'يبیت', 'والعلة', 'التحقيق', 'سوءٍ', 'الخب', 'قرءانا', 'وتارة', 'يعتبروه', 'التشكك', 'دراسة', 'الحروب', 'ال', 'يشرعون', 'الأب', 'قضى', 'وللأسف', 'بلزوم', 'الفسيولوجي', 'ولقد', 'دور', 'تاريخ', 'والخلق', 'السبع', 'الكرام', 'القبيلة', 'خمس', 'الضلال', 'يولد', 'تشنعها', 'وتجمعهم', 'تكرار', 'الأمرين', 'ولذلك', 'الذمام', 'أضمرته', 'المستشرقون', 'لفهم', 'قائل', 'والخزي', 'متفائل', 'العرب', 'الجمع', 'مناسبا', 'والأسلوب', 'المحبة', 'المسألة', 'يهزم', 'وتوريث', 'أغرى', 'الزمان', 'تعليمك', 'ليستطيعوا', 'الرزية', 'والتطوع', 'يستنبط', 'إذا', 'السامع', 'فهل', 'التخصيص', 'يتحدد', 'الاقتصاد', 'فهذه', 'النهائي', 'والخير', 'فكيف', 'أخته', 'مظلما', 'عدوانية', 'مرقص', 'وعترته', 'وينجرفوا', 'مالك', 'وصية', 'القرما', 'الرفض', 'جزيت', 'هاما', 'A', 'مر', 'السيكولوجي', 'نبينا', 'رضي', 'للمكروه', 'تطور', 'أنواعه', 'وقسوة',  ...

# %%
def delete_letter(word, verbose=False):
    delete_l = []
    split_l = []
    for c in range(len(word)):
        split_l.append((word[:c],word[c:]))
    for a,b in split_l:
        delete_l.append(a+b[1:])          
    if verbose: print(f"input word {word}, \nsplit_l = {split_l}, \ndelete_l = {delete_l}")

    return delete_l

def insert_letter(word, verbose=False):
    letters="ابتثجحخدذرزسشصضطظعغفقلكمونيةؤءئ"
   # letters = 'abcdefghijklmnopqrstuvwxyz'
    insert_l = []
    split_l = []
    for c in range(len(word)+1):
        split_l.append((word[0:c],word[c:]))
    insert_l = [ a + l + b for a,b in split_l for l in letters]
    if verbose: print(f"Input word {word} \nsplit_l = {split_l} \ninsert_l = {insert_l}")
    return insert_l


def switch_letter(word, verbose=False):

    def swap(c, i, j):
        c = list(c)
        c[i], c[j] = c[j], c[i]
        return ''.join(c)    
    switch_l = []
    split_l = []
    len_word=len(word)
    ### START CODE HERE ###
    for c in range(len_word):
        split_l.append((word[:c],word[c:]))
    switch_l = [a + b[1] + b[0] + b[2:] for a,b in split_l if len(b) >= 2]      
    if verbose: print(f"Input word = {word} \nsplit_l = {split_l} \nswitch_l = {switch_l}") 
    return switch_l
def replace_letter(word, verbose=False):
    letters="ابتثجحخدذرزسشصضطظعغفقلكمونيةؤءئ"
    replace_l = []
    split_l = []
    for c in range(len(word)):
        split_l.append((word[0:c],word[c:]))
    replace_l = [a + l + (b[1:] if len(b)> 1 else '') for a,b in split_l if b for l in letters]
    replace_set=set(replace_l)    
    replace_set.remove(word)
    replace_l = sorted(list(replace_set))
    if verbose: print(f"Input word = {word} \nsplit_l = {split_l} \nreplace_l {replace_l}")   
    return replace_l

def edit_one_letter(word, allow_switches = True):
    edit_one_set = set()
    edit_one_set.update(delete_letter(word))
    if allow_switches:
        edit_one_set.update(switch_letter(word))
    edit_one_set.update(replace_letter(word))
    edit_one_set.update(insert_letter(word))
    return edit_one_set

# %%
def get_corrections(word, probs, vocab, n=2, verbose = False):
    suggestions = []
    n_best = []
    
    ### START CODE HERE ###
    suggestions = list( edit_one_letter(word).intersection(vocab) )
    n_best = [[s,probs[s]] for s in list(reversed(suggestions))]
    ### END CODE HERE ###
    if verbose: print("suggestions = ", suggestions)

    return n_best

# %%
my_word = "علم"
tmp_corrections = get_corrections(my_word, probs, vocab, 2, verbose=False)
for i, word_prob in enumerate(tmp_corrections):
    print(f"word {i}: {word_prob[0]}, probability {word_prob[1]:.6f}")
# Out:
# word 0: علمك, probability 0.000076
# word 1: علو, probability 0.000076
# word 2: تعلم, probability 0.000302
# word 3: سلم, probability 0.000076
# word 4: علمي, probability 0.000076
# word 5: يعلم, probability 0.000151
# word 6: فلم, probability 0.000529
# word 7: حلم, probability 0.000076
# word 8: عام, probability 0.000151
# word 9: علي, probability 0.000076
# word 10: ولم, probability 0.001057
# word 11: عمل, probability 0.000378
# word 12: علة, probability 0.000906
# word 13: علل, probability 0.000076
# word 14: عدم, probability 0.000302
# word 15: ظلم, probability 0.000076
# word 16: لم, probability 0.002643
# word 17: علما, probability 0.000151
